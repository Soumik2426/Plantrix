# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in c:\users\user\anaconda3\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\users\user\anaconda3\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in c:\users\user\anaconda3\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 4090

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 64
EPOCHS_PHASE1 = 5
EPOCHS_PHASE2 = 10
DATA_DIR = "Dataset"

# %%
train_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomResizedCrop(IMAGE_SIZE, scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
full_dataset = datasets.ImageFolder(DATA_DIR, transform=train_transform)
class_names = full_dataset.classes
num_classes = len(class_names)

print("Classes:", class_names)
print("Total images:", len(full_dataset))
# Out:
# Classes: ['Bacterial Blight', 'Cercospora', 'Healthy Coffee Leaf', 'Healthy Sugarcane Leaf', 'Mosaic', 'RedRot', 'Rust Coffee Leaf', 'Rust Sugarcane Leaf', 'Yellow']
# Total images: 4915

# %%
train_size = int(0.7 * len(full_dataset))
val_size = int(0.2 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_ds, val_ds, test_ds = random_split(full_dataset, [train_size, val_size, test_size])

# %%
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# %%
images, labels = next(iter(train_loader))
plt.figure(figsize=(10, 10))
for i in range(9):
    img = images[i].permute(1, 2, 0).numpy()
    img = np.clip(img * np.array([0.229, 0.224, 0.225]) + 
                  np.array([0.485, 0.456, 0.406]), 0, 1)
    plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(class_names[labels[i]])
    plt.axis("off")
plt.show()

# %%
model = models.efficientnet_b0(weights="IMAGENET1K_V1")

# Freeze all feature extractor layers
for param in model.features.parameters():
    param.requires_grad = False

# Replace classifier for your dataset
num_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_features, num_classes)

model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
scaler = torch.amp.GradScaler("cuda")

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# %%
from tqdm import tqdm

# %%
print("PHASE 1: Training classifier only")

# ✅ ADD THIS BEFORE LOOP
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(EPOCHS_PHASE1):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS_PHASE1}", unit="batch")

    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        with torch.amp.autocast("cuda"):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    # ---- VALIDATION (INSIDE LOOP ✅) ----
    model.eval()
    val_loss = 0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct_val += (preds == labels).sum().item()
            total_val += labels.size(0)

    # ---- CALCULATE METRICS ----
    val_loss = val_loss / len(val_loader)
    val_acc = correct_val / total_val

    train_loss_epoch = train_loss / len(train_loader)
    train_acc_epoch = correct / total

    # ---- STORE VALUES ----
    train_losses.append(train_loss_epoch)
    train_accuracies.append(train_acc_epoch)

    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    # ---- SUMMARY ----
    print(f"Epoch [{epoch+1}/{EPOCHS_PHASE1}]")
    print(f"Train Loss: {train_loss_epoch:.4f} | Train Acc: {train_acc_epoch:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    print("-" * 50)
# Out:
# PHASE 1: Training classifier only
# Epoch 1/5: 100%|████████████████████████████████████████████████████████████████████| 54/54 [02:07<00:00,  2.37s/batch]
# Epoch [1/5]
# Train Loss: 0.1157 | Train Acc: 0.9628
# Val Loss: 0.1474 | Val Acc: 0.9522
# --------------------------------------------------
# Epoch 2/5: 100%|████████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.39s/batch]
# Epoch [2/5]
# Train Loss: 0.1048 | Train Acc: 0.9654
# Val Loss: 0.1485 | Val Acc: 0.9522
# --------------------------------------------------
# Epoch 3/5: 100%|████████████████████████████████████████████████████████████████████| 54/54 [02:08<00:00,  2.38s/batch]
# Epoch [3/5]
# Train Loss: 0.1175 | Train Acc: 0.9610
# Val Loss: 0.1397 | Val Acc: 0.9552
# --------------------------------------------------
# Epoch 4/5: 100%|████████████████████████████████████████████████████████████████████| 54/54 [02:08<00:00,  2.39s/batch]
# Epoch [4/5]
# Train Loss: 0.1032 | Train Acc: 0.9631
# Val Loss: 0.1593 | Val Acc: 0.9440
# --------------------------------------------------
# Epoch 5/5: 100%|████████████████████████████████████████████████████████████████████| 54/54 [02:08<00:00,  2.38s/batch]
# Epoch [5/5]
# Train Loss: 0.0980 | Train Acc: 0.9648
# Val Loss: 0.1221 | Val Acc: 0.9542
# --------------------------------------------------

# %%
for param in model.features[-2:].parameters():
    param.requires_grad = True

optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

# %%
print("PHASE 2: Fine-tuning entire model")

for epoch in range(EPOCHS_PHASE2):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS_PHASE2}", unit="batch")

    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        with torch.amp.autocast("cuda"):
            outputs = model(images)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        train_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    # ---- VALIDATION ----
    model.eval()
    val_loss = 0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct_val += (preds == labels).sum().item()
            total_val += labels.size(0)

    # ---- CALCULATE METRICS ----
    val_loss = val_loss / len(val_loader)
    val_acc = correct_val / total_val

    train_loss_epoch = train_loss / len(train_loader)
    train_acc_epoch = correct / total

    # ---- STORE VALUES (CONTINUE SAME LISTS) ----
    train_losses.append(train_loss_epoch)
    train_accuracies.append(train_acc_epoch)

    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    # ---- SUMMARY ----
    print(f"Epoch [{epoch+1}/{EPOCHS_PHASE2}]")
    print(f"Train Loss: {train_loss_epoch:.4f} | Train Acc: {train_acc_epoch:.4f}")
    print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
    print("-" * 50)
# Out:
# PHASE 2: Fine-tuning entire model
# Epoch 1/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.39s/batch]
# Epoch [1/10]
# Train Loss: 0.0894 | Train Acc: 0.9724
# Val Loss: 0.1281 | Val Acc: 0.9542
# --------------------------------------------------
# Epoch 2/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:10<00:00,  2.41s/batch]
# Epoch [2/10]
# Train Loss: 0.0878 | Train Acc: 0.9721
# Val Loss: 0.1224 | Val Acc: 0.9573
# --------------------------------------------------
# Epoch 3/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.41s/batch]
# Epoch [3/10]
# Train Loss: 0.0958 | Train Acc: 0.9674
# Val Loss: 0.1329 | Val Acc: 0.9624
# --------------------------------------------------
# Epoch 4/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.41s/batch]
# Epoch [4/10]
# Train Loss: 0.0933 | Train Acc: 0.9689
# Val Loss: 0.1446 | Val Acc: 0.9573
# --------------------------------------------------
# Epoch 5/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.40s/batch]
# Epoch [5/10]
# Train Loss: 0.0821 | Train Acc: 0.9750
# Val Loss: 0.1349 | Val Acc: 0.9522
# --------------------------------------------------
# Epoch 6/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:11<00:00,  2.44s/batch]
# Epoch [6/10]
# Train Loss: 0.0744 | Train Acc: 0.9776
# Val Loss: 0.1207 | Val Acc: 0.9603
# --------------------------------------------------
# Epoch 7/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:12<00:00,  2.45s/batch]
# Epoch [7/10]
# Train Loss: 0.0663 | Train Acc: 0.9817
# Val Loss: 0.1505 | Val Acc: 0.9512
# --------------------------------------------------
# Epoch 8/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:11<00:00,  2.44s/batch]
# Epoch [8/10]
# Train Loss: 0.0665 | Train Acc: 0.9797
# Val Loss: 0.1418 | Val Acc: 0.9552
# --------------------------------------------------
# Epoch 9/10: 100%|███████████████████████████████████████████████████████████████████| 54/54 [02:11<00:00,  2.44s/batch]
# Epoch [9/10]
# Train Loss: 0.0714 | Train Acc: 0.9791
# Val Loss: 0.1325 | Val Acc: 0.9481
# --------------------------------------------------
# Epoch 10/10: 100%|██████████████████████████████████████████████████████████████████| 54/54 [02:09<00:00,  2.40s/batch]
# Epoch [10/10]
# Train Loss: 0.0621 | Train Acc: 0.9791
# Val Loss: 0.1214 | Val Acc: 0.9634
# --------------------------------------------------

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

print("Final Test Accuracy:", (correct / total) * 100, "%")
# Out:
# Final Test Accuracy: 96.7479674796748 %

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,5))

# 🔹 Accuracy Graph
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, marker='o', linewidth=2.5, label="Train Accuracy")
plt.plot(val_accuracies, marker='s', linewidth=2.5, label="Validation Accuracy")

plt.axvline(x=EPOCHS_PHASE1-1, linestyle='--', linewidth=2)

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model Accuracy", fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# 🔹 Loss Graph
plt.subplot(1, 2, 2)
plt.plot(train_losses, marker='o', linewidth=2.5, label="Train Loss")
plt.plot(val_losses, marker='s', linewidth=2.5, label="Validation Loss")

plt.axvline(x=EPOCHS_PHASE1-1, linestyle='--', linewidth=2)

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model Loss", fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\reefgpu\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(all_labels, all_preds)

# Row-wise percentage
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

# Create compact annotation (smaller + clean)
annot = np.empty_like(cm).astype(str)

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        annot[i, j] = f"{cm[i,j]}\n{cm_percent[i,j]:.0f}%"   # clean format

# Plot
plt.figure(figsize=(10,8))

sns.heatmap(cm, annot=annot, fmt="", cmap="Blues",
            xticklabels=class_names,
            yticklabels=class_names,
            linewidths=0.8, linecolor='black',
            annot_kws={"size":9})   # smaller text

plt.xlabel("Predicted", fontsize=12)
plt.ylabel("Actual", fontsize=12)
plt.title("Confusion Matrix", fontsize=14, fontweight='bold')

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
import pandas as pd
import matplotlib.pyplot as plt

report = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True)
df = pd.DataFrame(report).transpose()

# Remove accuracy row
df = df.iloc[:-1, :]

plt.figure(figsize=(10,6))

ax = df[['precision','recall','f1-score']].plot(kind='bar')

plt.title("Precision, Recall, F1 Score", fontweight='bold')
plt.ylabel("Score")
plt.xlabel("Classes")

plt.xticks(rotation=45, ha='right')
plt.grid(True, linestyle='--', alpha=0.6)

# ✅ Move legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1,1))

plt.tight_layout()
plt.show()

# %%
import torch.nn.functional as F

all_probs = []
all_labels = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        probs = F.softmax(outputs, dim=1)

        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt

# Convert labels to one-hot
n_classes = len(class_names)
y_true = label_binarize(all_labels, classes=range(n_classes))
y_score = np.array(all_probs)

plt.figure(figsize=(8,6))

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, linewidth=2, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")

plt.plot([0,1], [0,1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Multiclass)")
plt.legend(loc='lower right')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize

plt.figure(figsize=(8,6))

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_true[:, i], y_score[:, i])

    plt.plot(recall, precision, linewidth=2, label=class_names[i])

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc='lower left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import torch.nn.functional as F

all_probs = []
all_labels = []
all_preds = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        probs = F.softmax(outputs, dim=1)
        _, preds = torch.max(outputs, 1)

        all_probs.extend(probs.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.preprocessing import label_binarize
import numpy as np

# Convert to numpy
y_true = np.array(all_labels)
y_pred = np.array(all_preds)
y_prob = np.array(all_probs)

# 🔹 Precision, Recall, F1
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

# 🔹 ROC AUC (multiclass)
n_classes = len(class_names)
y_true_bin = label_binarize(y_true, classes=range(n_classes))

roc_auc = roc_auc_score(y_true_bin, y_prob, multi_class='ovr')

# 🔹 Log Loss
logloss = log_loss(y_true, y_prob)

# 🔹 Print results
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1, 4))
print("ROC AUC Score:", round(roc_auc, 4))
print("Log Loss:", round(logloss, 4))
# Out:
# Precision: 0.9757
# Recall: 0.9756
# F1 Score: 0.9756
# ROC AUC Score: 0.9989
# Log Loss: 0.0938

# %%
# Create Models folder if not present
model_folder = "Models"
os.makedirs(model_folder, exist_ok=True)

# Count existing models to determine next name
existing_models = [f for f in os.listdir(model_folder) if f.startswith("Model") and f.endswith(".pth")]
next_model_number = len(existing_models) + 1
model_filename = f"Model{next_model_number}.pth"

save_path = os.path.join(model_folder, model_filename)

# Save model + class names
torch.save({
    'model_state_dict': model.state_dict(),
    'class_names': class_names
}, save_path)

print(f"Model saved successfully as {save_path}")
# Out:
# Model saved successfully as Models\Model2.pth
